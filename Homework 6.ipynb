# %% [markdown]
# # Task 4
#
# Support Vector Machines (SVM) is a supervised learning algorithm, which can be applicable to both classification and regression. The data set provided contains normal and fraudulent transactions in excel file “Week6-Fraud_data” in sheets “FraudTrain” and “FraudTest”. Using Support Machine Model (SVM), predict whether the transactions are Normal or Fraudulent based on the features of the transactions in the dataset.

# %%
# import the standard labries
import pandas as pd
import numpy  as np
from matplotlib import  pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.svm import SVC

# %% [markdown]
# # 1. load the dataset

# %%
train = pd.read_excel('Week6-Fraud_data.xlsx', sheet_name='fraudTrain')

# %%
test = pd.read_excel('Week6-Fraud_data.xlsx', sheet_name='fraudTest')

# %%
test
# Out:
#         Unnamed: 0 trans_date_trans_time            cc_num  \
# 0                0   2020-06-21 12:14:25  2291163933867240
# 1                1   2020-06-21 12:14:33  3573030041201290
# 2                2   2020-06-21 12:14:53  3598215285024750
# 3                3   2020-06-21 12:15:15  3591919803438420
# 4                4   2020-06-21 12:15:17  3526826139003040
# ...            ...                   ...               ...
# 555714      555714   2020-12-31 23:59:07    30560609640617
# 555715      555715   2020-12-31 23:59:09  3556613125071650
# 555716      555716   2020-12-31 23:59:15  6011724471098080
# 555717      555717   2020-12-31 23:59:24     4079773899158
# 555718      555718   2020-12-31 23:59:34  4170689372027570
#
#                                     merchant        category     amt    first  \
# 0                      fraud_Kirlin and Sons   personal_care    2.86     Jeff
# 1                       fraud_Sporer-Keebler   personal_care   29.84   Joanne
# ...

# %%
train.head()

# %%
df = pd.concat([train, test], ignore_index=True)

# %% [markdown]
# # 2.Data Preprocessing

# %%
#check the missing 
df.isnull().sum()
# Out:
# trans_date_trans_time          0
# cc_num                         0
# merchant                       0
# category                       0
# amt                            0
# first                          0
# last                           0
# gender                         0
# street                         0
# city                           0
# state                          0
# zip                            0
# lat                            0
# long                           0
# city_pop                       0
# job                            0
# dob                            0
# unix_time                      0
# merch_lat                      0
# merch_long                     0
# is_fraud                       0
# Data_FLAG                      0
# Unnamed: 0               1048575
# trans_num                1048575
# dtype: int64

# %% [markdown]
# there is no missing vlaue in data

# %%
# Remove unnamed columns
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# %%
df.drop(columns=['trans_num'], inplace=True)

# %%
df.dtypes
# Out:
# trans_date_trans_time    datetime64[ns]
# cc_num                            int64
# merchant                         object
# category                         object
# amt                             float64
# first                            object
# last                             object
# gender                           object
# street                           object
# city                             object
# state                            object
# zip                               int64
# lat                             float64
# long                            float64
# city_pop                          int64
# job                              object
# dob                      datetime64[ns]
# unix_time                         int64
# merch_lat                       float64
# merch_long                      float64
# is_fraud                          int64
# Data_FLAG                        object
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

# Identify object columns
object_cols = df.select_dtypes(include=['object']).columns

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Apply LabelEncoder to each object column
for col in object_cols:
    df[col] = label_encoder.fit_transform(df[col])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_encode.py:183, in _unique_python(values, return_inverse, return_counts)
#     181 uniques_set, missing_values = _extract_missing(uniques_set)
# --> 183 uniques = sorted(uniques_set)
#     184 uniques.extend(missing_values.to_list())
#
# TypeError: '<' not supported between instances of 'str' and 'int'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 11
#       9 # Apply LabelEncoder to each object column
#      10 for col in object_cols:
# ---> 11     df[col] = label_encoder.fit_transform(df[col])
#
# File ~\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:111, in LabelEncoder.fit_transform(self, y)
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
# Initialize the LabelEncoder
label_encoder = LabelEncoder()
# Fit and transform the 'merchant' column
df['merchant'] = label_encoder.fit_transform(df['merchant'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_encode.py:183, in _unique_python(values, return_inverse, return_counts)
#     181 uniques_set, missing_values = _extract_missing(uniques_set)
# --> 183 uniques = sorted(uniques_set)
#     184 uniques.extend(missing_values.to_list())
#
# TypeError: '<' not supported between instances of 'str' and 'int'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 4
#       2 label_encoder = LabelEncoder()
#       3 # Fit and transform the 'merchant' column
# ----> 4 df['merchant'] = label_encoder.fit_transform(df['merchant'])
#
# File ~\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:111, in LabelEncoder.fit_transform(self, y)
# ...

# %%
# Initialize the LabelEncoder
label_encoder = LabelEncoder()
# Fit and transform the 'merchant' column
df['category'] = label_encoder.fit_transform(df['category'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_encode.py:183, in _unique_python(values, return_inverse, return_counts)
#     181 uniques_set, missing_values = _extract_missing(uniques_set)
# --> 183 uniques = sorted(uniques_set)
#     184 uniques.extend(missing_values.to_list())
#
# TypeError: '<' not supported between instances of 'str' and 'int'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 4
#       2 label_encoder = LabelEncoder()
#       3 # Fit and transform the 'merchant' column
# ----> 4 df['category'] = label_encoder.fit_transform(df['category'])
#
# File ~\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:111, in LabelEncoder.fit_transform(self, y)
# ...

# %%
# Initialize the LabelEncoder
label_encoder = LabelEncoder()
# Fit and transform the 'merchant' column
train['first'] = label_encoder.fit_transform(train['first'])

# %%
# Initialize the LabelEncoder
label_encoder = LabelEncoder()
# Fit and transform the 'merchant' column
train['last'] = label_encoder.fit_transform(train['last'])

# %%
# Initialize the LabelEncoder
label_encoder = LabelEncoder()
# Fit and transform the 'merchant' column
train['gender'] = label_encoder.fit_transform(train['gender'])

# %%
# Initialize the LabelEncoder
label_encoder = LabelEncoder()
# Fit and transform the 'merchant' column
train['street'] = label_encoder.fit_transform(train['street'])

# %%
# Initialize the LabelEncoder
label_encoder = LabelEncoder()
# Fit and transform the 'merchant' column
train['city'] = label_encoder.fit_transform(train['city'])

# %%
# Initialize the LabelEncoder
label_encoder = LabelEncoder()
# Fit and transform the 'merchant' column
train['state'] = label_encoder.fit_transform(train['state'])

# %%
# Initialize the LabelEncoder
label_encoder = LabelEncoder()
# Fit and transform the 'merchant' column
train['job'] = label_encoder.fit_transform(train['job'])

# %%
# Initialize the LabelEncoder
label_encoder = LabelEncoder()
# Fit and transform the 'merchant' column
train['Data_FLAG'] = label_encoder.fit_transform(train['Data_FLAG'])

# %%
train
# Out:
#         trans_date_trans_time               cc_num  merchant  category  \
# 0         2019-01-01 00:00:18     2703186189652090       514         8
# 1         2019-01-01 00:00:44         630423337322       241         4
# 2         2019-01-01 00:00:51       38859492057661       390         0
# 3         2019-01-01 00:01:16     3534093764340240       360         2
# 4         2019-01-01 00:03:06      375534208663984       297         9
# ...                       ...                  ...       ...       ...
# 1048570   2020-03-10 16:07:29     6011975266774120       166         5
# 1048571   2020-03-10 16:07:50     4839043708100390       110         9
# 1048572   2020-03-10 16:08:31         571844099986       456         6
# 1048573   2020-03-10 16:08:38  4646845581490329600       620         5
# 1048574   2020-03-10 16:08:50     2283743876903620        83         9
#
#             amt  first  last  gender  street  city  ...      lat      long  \
# ...

# %%
# Define features (X) and target (y)
X = train.drop(columns=['is_fraud'])  # Input variables
y = train['is_fraud']                 # Output/Target variable
